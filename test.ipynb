# %%
using Pkg
Pkg.add("GraphPlot")
Pkg.add("Graphs")
Pkg.add("Compose")
Pkg.add("Cairo")
Pkg.add("Fontconfig")

# %%
using GraphPlot
using Graphs
using Compose
using Cairo
using Fontconfig
using Random

# %%
g = Graphs.watts_strogatz(100,4,0.5)
# g = watts_strogatz(100,4,0.5)
gplot(g)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.509877145325238cx, 0.15892385142579016cy), (0.49184773410623794cx, -0.0450095583281436cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.48710042579624907cx, 0.18486715696767234cy), (0.13713689533962675cx, 0.19944438559582986cy)]), Compose.LinePrimitive{Tuple{Measure, Mea
# ...

# %%
g = Graphs.barabasi_albert(150, 2) 
fig = gplot(g)
Compose.draw(PNG("./tmp/barabasi_albert_graph.png", 10cm, 10cm), fig)

# %%
g = Graphs.SimpleGraph(3)
Graphs.add_edge!(g,1,2)
Graphs.add_edge!(g, 2, 3)
Graphs.add_edge!(g, 3, 1)
gplot(g)

# %%
g = Graphs.smallgraph(:karate)
gplot(g)

# %%
g = smallgraph(:karate)
Random.seed!(97330)
g
# loc_x, loc_y = spring_layout(g)
# gplot(g, loc_x=loc_x, loc_y=loc_y)

# %%
g = LightGraphs.barabasi_albert(100, 4)
gplot(g)
# gplot(10,20)
